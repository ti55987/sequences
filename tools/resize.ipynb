# %%
import os
from pathlib import Path
from PIL import Image

# %%
def load_image(img_path: str) -> Image:
    try:
        with Image.open(img_path) as img:
            # Force load image data into memory before the file closes
            img.load()
            print(f"Loaded: {img_path.name} | Dimensions: {img.size} | Mode: {img.mode}")
            
            # Example processing:
            # resized = img.resize((300, 300))
    except Exception as e:
        print(f"Failed to read {img_path.name}: {e}")
    return img

def resize_and_save(img: Image, output_path: str, size: tuple = (300, 300)):
    # Convert to RGB if image has an alpha channel (PNG/RGBA) to avoid JPEG save errors
    if img.mode in ("RGBA", "P"):
        img = img.convert("RGB")
    
    # Resize using high-quality downsampling (LANCZOS)
    resized_img = img.resize(size, Image.Resampling.LANCZOS)
    if len(output_path) > 0:
        # Save as JPEG
        resized_img.save(output_path, format="JPEG", quality=90)
    
    return resized_img


image_dir = Path("../images/")
output_dir = Path("../images/resized/")
categories = ["animal", "building"]
for fi, c in enumerate(categories):
    # Use *.png (case-sensitive on Linux) or rglob for recursive search
    for i, img_path in enumerate(image_dir.glob(f"{c}*.png")):
        img = load_image(img_path)
        # Create output directory if it does not exist
        out_folder = output_dir / f"img{fi+1}"
        out_folder.mkdir(parents=True, exist_ok=True)
 
        resized_img = resize_and_save(img, f"{out_folder}/image{i+1}.jpg")
# Out:
# Loaded: animal_horse-07.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_parrot-01.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_leopard-01.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_cat-00.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_lizard-00.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_frog-02.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_dog-00.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_elephant-00.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_koala-01.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_giraffe-06.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_owl-02.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_fish-00.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: animal_beaver-02.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_lighthouse-00.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_bell_tower-00.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_cabin-03.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_fortress-01.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_barn-09.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_observatory-01.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_futuristic_building-00.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_igloo-01.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_farm-02.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_pagoda-04.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_modern_building-04.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_greenhouse-03.png | Dimensions: (512, 512) | Mode: RGB
# Loaded: building_polar_base-01.png | Dimensions: (512, 512) | Mode: RGB

# %%
# Example usage
resize_and_save("input.png", "output_300x300.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 16
#      12         # Save as JPEG
#      13         resized_img.save(output_path, format="JPEG", quality=90)
#      14
#      15 # Example usage
# ---> 16 resize_and_save("input.png", "output_300x300.jpg")
#
# Cell In[4], line 4, in resize_and_save(input_path, output_path, size)
#       3 def resize_and_save(input_path: str, output_path: str, size: tuple = (300, 300)):
# ----> 4     with Image.open(input_path) as img:
#       5         # Convert to RGB if image has an alpha channel (PNG/RGBA) to avoid JPEG save errors
#       6         if img.mode in ("RGBA", "P"):
#       7             img = img.convert("RGB")
#
# File ~/miniconda3/envs/dl4rl-k3/lib/python3.12/site-packages/PIL/Image.py:3635, in open(fp, mode, formats)
#    3633 if is_path(fp):
#    3634     filename = os.fspath(fp)
# -> 3635     fp = builtins.open(filename, "rb")
#    3636     exclusive_fp = True
#    3637 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input.png'
