# %% [markdown]
# # Sequence generation for the pseudoRWM set of experiments

# %% [markdown]
# ## Import statements and utilities

# %%
import numpy as np
import pandas as pd

# %%
def shuffle_along_axis(arr, axis):
    idx = np.random.rand(*arr.shape).argsort(axis=axis)
    return np.take_along_axis(arr, idx, axis=axis)


def shuffled(arr):
    arr_shuffled = arr.copy()
    np.random.shuffle(arr_shuffled)
    return arr_shuffled


def choose_n_and_delete(arr, N):
    chosen = np.random.choice(arr, size=N, replace=False)
    arr = np.delete(arr, np.where(np.isin(arr, chosen)))
    return chosen, arr

# %% [markdown]
# ## Settings

# %%
exp_type = "v1_rlwm"
num_conditions = 1  # number of different file sequences to generate (change if needed)
reps_dict = {
    "reverse_points": 12,
    "v1_rlwm": 12,
}  # number of repetitions after the first presentation
num_reps = reps_dict[
    exp_type
]  # number of stimulus repetitions (after first presentation; change if needed)
exact_reps = True # should the number of repetitions be exact or ok to exceed by 1?
#DIR = "/Users/ccnlab/Development/sequences/reverse-points/seqv2/"
DIR = "/Users/ccnlab/Development/sequences/shaping/v1_rlwm/"

# %% [markdown]
# ## Main sequence creation function

# %%
COLNAMES = [
    "stim",
    "correct_key",
    "set_size",
    "block",
    "img_folder",
    "stim_img",
    "trial_type",
]

# set size -> rows of [n_stimuli for key 0, key 1, key 2]
# e.g. [1, 2, 3] => 1 stim on key 0, 2 on key 1, 3 on key 2 (6 total)
SET_SIZE_TO_KEY_LIST = {
    2: np.array(
        [
            [1, 0, 1],
            [1, 1, 0],
            [0, 1, 1],
            [1, 0, 1],
        ]
    ),
    6: np.array(
        [
            [1, 2, 3],
            [1, 3, 2],
            [2, 2, 2],
            [3, 2, 1],
        ]
    ),
}


class PseudoRWMSequenceMaker:
    def __init__(self, exp_type, num_reps, to_dir=DIR, num_keys=3):
        self.exp_type = exp_type
        self.num_reps = num_reps
        self.to_dir = to_dir
        self.num_keys = num_keys
        self.max_stims = num_reps
        self.set_size_to_key_list = {
            ns: arr.copy() for ns, arr in SET_SIZE_TO_KEY_LIST.items()
        }

    def make_sequences(self, s_i, block_structure, stim_sets):
        """
        block_structure: list of (set_size, trial_type) per block
        stim_sets: image folder id per block
        """
        block_rules = self._make_block_rules(block_structure)

        blocks = []
        for block_i, (ns, trial_type) in enumerate(block_structure):
            prototype = self._make_seq_prototype(ns)
            correct_keys = np.vectorize(block_rules[block_i].get)(prototype - 1)

            block = np.vstack(
                [
                    prototype,
                    correct_keys,
                    np.full(len(prototype), ns),
                    np.full(len(prototype), block_i + 1),
                    np.full(len(prototype), stim_sets[block_i]),
                    np.full(len(prototype), trial_type),
                ]
            )
            blocks.append(block)

        train_seq = np.hstack(blocks)
        np.savetxt(f"{self.to_dir}seq{s_i}_practice.csv", train_seq, delimiter=",")
        return train_seq

    def _make_block_rules(self, block_structure):
        """stim_idx (0-based) -> correct key, per block. Shuffles key counts within rows."""
        key_pools = {
            ns: shuffle_along_axis(keys, axis=1).tolist()
            for ns, keys in self.set_size_to_key_list.items()
        }

        block_rules = []
        for ns, _ in block_structure:
            counts = key_pools[ns].pop()
            # expand [1, 2, 3] -> [0, 1, 1, 2, 2, 2], then map stim i -> that key
            keys_for_stims = [
                key_i
                for key_i in range(self.num_keys)
                for _ in range(counts[key_i])
            ]
            block_rules.append(dict(enumerate(keys_for_stims)))
        return block_rules

    def _make_block_stimuli(self, block_structure):
        """stim_idx (0-based) -> image number (1-based), per block."""
        block_stimuli = []
        for ns, _ in block_structure:
            images = (np.random.permutation(self.max_stims) + 1)[:ns]
            block_stimuli.append(dict(enumerate(images)))

        return block_stimuli

    def _make_seq_prototype(self, set_size):
        """Stimulus indices 1..set_size, shuffled each repetition cycle."""
        cycles = [
            shuffled(np.arange(1, set_size + 1))
            for _ in range(self.num_reps + 1)
        ]
        return np.hstack(cycles)

# %% [markdown]
# ## Create sequences

# %%
# seqmkr = pseudoRWMSequenceMaker(exp_type=exp_type, num_reps=num_reps, num_conditions=num_conditions, use_matlab=use_matlab, exact_reps=exact_reps)
seqmkr = PseudoRWMSequenceMaker(
    exp_type=exp_type,
    num_reps=num_reps,
)

# list of (set_size, TRIAL TYPES)
# trial_types: array  where each element represent the sequence
# of trial types (1 = Points/Standard, 0 = Goals/Reverse) a participant will experience
block_structure = [
    (2, 1),
]
for i, blocks in enumerate(block_structure):
    # can do max_consec_goal_reps=4 for Reps3 and 16 for Conf3 (a bit slow)
    df = seqmkr.make_sequences(s_i=i+1, block_structure=[blocks], stim_sets=[i+1])

# %% [markdown]
# ## Checks

# %%
# exp_type = "pseudoRWMReps3"
dir = "/Users/ccnlab/Development/sequences/shaping/v1_rlwm/"
for i in np.arange(1, 2):
    df = pd.read_csv(
        f"{dir}/seq{i}_practice.csv", header=None
    ).T

    colnames = [
        "stim",
        "correct_key",
        "set_size",
        "block",
        "img_folder",
        #"stim_img",
        "trial_type",
        # "goal_img",
        # "nongoal_img",
    ]

    df.columns = colnames
    print(df.groupby(["set_size", "trial_type"]).block.nunique(), i, df.img_folder.unique())

df.head()
# Out:
# set_size  trial_type
# 2.0       1.0           1
# Name: block, dtype: int64 1 [1.]

# %%
df.to_csv(f"{dir}/seq{i}_practice.csv", index=False)
